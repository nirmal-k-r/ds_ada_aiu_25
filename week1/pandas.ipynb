# %%
import numpy as np
import pandas as pd

# %%
#Load dataset
df=pd.read_csv('coffee.csv',sep=';',encoding="utf-8")
df
# Out:
#           ID  Age  Gender  Country  Coffee_Intake  Caffeine_mg  Sleep_Hours  \
# 0          1   40    Male  Germany            3.5        328.1          7.5
# 1          2   33    Male  Germany            1.0         94.1          6.2
# 2          3   42    Male  Brazil😂            5.3        503.7          5.9
# 3          4   53    Male  Germany            2.6        249.2          7.3
# 4          5   32  Female    Spain            3.1        298.0          5.3
# ...      ...  ...     ...      ...            ...          ...          ...
# 10003   9996   50  Female    Japan            2.1        199.8          6.0
# 10004   9997   18  Female       UK            3.4        319.2          5.8
# 10005   9998   26    Male    China            1.6        153.4          7.1
# 10006   9999   40  Female  Finland            3.4        327.1          7.0
# 10007  10000   42  Female   Brazil            2.9        277.5          6.4
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Country', 'Coffee_Intake', 'Caffeine_mg',
#        'Sleep_Hours', 'Sleep_Quality', 'BMI', 'Heart_Rate', 'Stress_Level',
#        'Physical_Activity_Hours', 'Health_Issues', 'Occupation', 'Smoking',
#        'Alcohol_Consumption'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       10008 non-null  int64
#  1   Age                      10008 non-null  int64
#  2   Gender                   10008 non-null  object
#  3   Country                  10007 non-null  object
#  4   Coffee_Intake            10008 non-null  float64
#  5   Caffeine_mg              10008 non-null  float64
#  6   Sleep_Hours              10008 non-null  float64
#  7   Sleep_Quality            10007 non-null  object
#  8   BMI                      10008 non-null  float64
#  9   Heart_Rate               10008 non-null  int64
#  10  Stress_Level             10007 non-null  object
#  11  Physical_Activity_Hours  10008 non-null  float64
#  12  Health_Issues            4067 non-null   object
#  13  Occupation               10008 non-null  object
# ...

# %%
df.describe()
# Out:
#                  ID           Age  Coffee_Intake   Caffeine_mg   Sleep_Hours  \
# count  10008.000000  10008.000000   10008.000000  10008.000000  10008.000000
# mean    4996.506795     34.946743       2.509702    238.458643      6.635152
# std     2889.193331     11.156788       1.449764    137.704042      1.222150
# min        1.000000     18.000000       0.000000      0.000000      3.000000
# 25%     2494.750000     26.000000       1.500000    138.800000      5.800000
# 50%     4996.500000     34.000000       2.500000    235.500000      6.600000
# 75%     7498.250000     43.000000       3.500000    331.900000      7.500000
# max    10000.000000     80.000000       8.200000    780.300000     10.000000
#
#                 BMI    Heart_Rate  Physical_Activity_Hours      Smoking  \
# count  10008.000000  10008.000000              10008.00000  10008.00000
# mean      23.986950     70.622102                  7.48785      0.20024
# ...

# %% [markdown]
# # sub-objectives (understanding the dataset)
#  - Compare gender balance across the dataset.
#  - Study correlations between stress and sleep quality, caffeine, physical activity.
#  - Compare stress levels across occupations.
#  - assess whether high caffeine + poor sleep participants exhibit higher stress or health issues
#  - Look for potential coffee addicts (who would be suitable for detox)

# %%
# gender, strss level, caffeine, sleep quality, physical activity, occupationm, health issues

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Country', 'Coffee_Intake', 'Caffeine_mg',
#        'Sleep_Hours', 'Sleep_Quality', 'BMI', 'Heart_Rate', 'Stress_Level',
#        'Physical_Activity_Hours', 'Health_Issues', 'Occupation', 'Smoking',
#        'Alcohol_Consumption'],
#       dtype='object')

# %%
df2=df[['ID', 'Gender', 'Coffee_Intake', 'Caffeine_mg',
       'Sleep_Hours', 'Sleep_Quality', 'BMI', 'Heart_Rate', 'Stress_Level',
       'Physical_Activity_Hours', 'Health_Issues', 'Occupation', 'Alcohol_Consumption']]

# %%
df2.head() #return top 5 rows
# Out:
#    ID  Gender  Coffee_Intake  Caffeine_mg  Sleep_Hours Sleep_Quality   BMI  \
# 0   1    Male            3.5        328.1          7.5          Good  24.9
# 1   2    Male            1.0         94.1          6.2          Good  20.0
# 2   3    Male            5.3        503.7          5.9          Fair  22.7
# 3   4    Male            2.6        249.2          7.3          Good  24.7
# 4   5  Female            3.1        298.0          5.3          Fair  24.1
#
#    Heart_Rate Stress_Level  Physical_Activity_Hours Health_Issues Occupation  \
# 0          78          Low                     14.5           NaN      Other
# 1          67          Low                     11.0           NaN    Service
# 2          59       Medium                     11.2          Mild     Office
# 3          71          Low                      6.6          Mild      Other
# 4          76       Medium                      8.5          Mild    Student
#
#    Alcohol_Consumption
# 0                    0
# ...

# %%
df2.tail()
# Out:
#           ID  Gender  Coffee_Intake  Caffeine_mg  Sleep_Hours Sleep_Quality  \
# 10003   9996  Female            2.1        199.8          6.0          Fair
# 10004   9997  Female            3.4        319.2          5.8          Fair
# 10005   9998    Male            1.6        153.4          7.1          Good
# 10006   9999  Female            3.4        327.1          7.0          Good
# 10007  10000  Female            2.9        277.5          6.4          Good
#
#         BMI  Heart_Rate Stress_Level  Physical_Activity_Hours Health_Issues  \
# 10003  30.5          50       Medium                     10.1      Moderate
# 10004  19.1          71       Medium                     11.6          Mild
# 10005  25.1          66          Low                     13.7           NaN
# 10006  19.3          80          Low                      0.1           NaN
# 10007  28.1          72          Low                      9.8           NaN
#
#        Occupation  Alcohol_Consumption
# ...

# %%
df2.head(10)
# Out:
#    ID  Gender  Coffee_Intake  Caffeine_mg  Sleep_Hours Sleep_Quality   BMI  \
# 0   1    Male            3.5        328.1          7.5          Good  24.9
# 1   2    Male            1.0         94.1          6.2          Good  20.0
# 2   3    Male            5.3        503.7          5.9          Fair  22.7
# 3   4    Male            2.6        249.2          7.3          Good  24.7
# 4   5  Female            3.1        298.0          5.3          Fair  24.1
# 5   5  Female            3.1        298.0          5.3          Fair  24.1
# 6   5  Female            3.1        298.0          5.3          Fair  24.1
# 7   5  Female            3.1        298.0          5.3          Fair  24.1
# 8   5  Female            3.1        298.0          5.3          Fair  24.1
# 9   5  Female            3.1        298.0          5.3          Fair  24.1
#
#    Heart_Rate Stress_Level  Physical_Activity_Hours Health_Issues Occupation  \
# ...

# %%
df2['Gender'] #xtract specific columnd
# Out:
# 0          Male
# 1          Male
# 2          Male
# 3          Male
# 4        Female
#           ...
# 10003    Female
# 10004    Female
# 10005      Male
# 10006    Female
# 10007    Female
# Name: Gender, Length: 10008, dtype: object

# %%
#selecting thie third row
df2.iloc[3:6]
# Out:
#    ID  Gender  Coffee_Intake  Caffeine_mg  Sleep_Hours Sleep_Quality   BMI  \
# 3   4    Male            2.6        249.2          7.3          Good  24.7
# 4   5  Female            3.1        298.0          5.3          Fair  24.1
# 5   5  Female            3.1        298.0          5.3          Fair  24.1
#
#    Heart_Rate Stress_Level  Physical_Activity_Hours Health_Issues Occupation  \
# 3          71          Low                      6.6          Mild      Other
# 4          76       Medium                      8.5          Mild    Student
# 5          76       Medium                      8.5          Mild    Student
#
#    Alcohol_Consumption
# 3                    0
# 4                    1
# 5                    1

# %% [markdown]
# # data cleaning
#  - filter relevant columns
#  - rename columns to meaningful names
#  - handle null values
#  - encoding
#  - handlign outliers

# %%
df2.columns
# Out:
# Index(['ID', 'Gender', 'Coffee_Intake', 'Caffeine_mg', 'Sleep_Hours',
#        'Sleep_Quality', 'BMI', 'Heart_Rate', 'Stress_Level',
#        'Physical_Activity_Hours', 'Health_Issues', 'Occupation',
#        'Alcohol_Consumption'],
#       dtype='object')

# %%
df2.drop(columns=['Alcohol_Consumption'], inplace=True) #inplace updates the current dataset
df2.columns
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_58882/2067202238.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['Alcohol_Consumption'], inplace=True) #inplace updates the current dataset
# Index(['ID', 'Gender', 'Coffee_Intake', 'Caffeine_mg', 'Sleep_Hours',
#        'Sleep_Quality', 'BMI', 'Heart_Rate', 'Stress_Level',
#        'Physical_Activity_Hours', 'Health_Issues', 'Occupation'],
#       dtype='object')

# %%
df2.rename(columns={'BMI': 'Bmi'},inplace=True)

df2.columns
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_58882/418177717.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns={'BMI': 'Bmi'},inplace=True)
# Index(['ID', 'Gender', 'Coffee_Intake', 'Caffeine_mg', 'Sleep_Hours',
#        'Sleep_Quality', 'Bmi', 'Heart_Rate', 'Stress_Level',
#        'Physical_Activity_Hours', 'Health_Issues', 'Occupation'],
#       dtype='object')

# %%
#check amount of null values
df2.isna().sum()
# Out:
# ID                            0
# Gender                        0
# Coffee_Intake                 0
# Caffeine_mg                   0
# Sleep_Hours                   0
# Sleep_Quality                 1
# Bmi                           0
# Heart_Rate                    0
# Stress_Level                  1
# Physical_Activity_Hours       0
# Health_Issues              5941
# Occupation                    0
# dtype: int64

# %%
# df2.dropna(inplace=True) #drop records with null values

# df2.info()

# %%
df2['Coffee_Intake'].mean()
# Out:
# np.float64(2.5097022382094325)

# %%
#replace null values with "No"

df2['Health_Issues'].fillna('No',inplace=True)
df2.isna().sum()
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_58882/1060747282.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Health_Issues'].fillna('No',inplace=True)
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_58882/1060747282.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df2.shape
# Out:
# (10008, 12)

# %%
df2.dropna(inplace=True)
df2.shape
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_58882/3446334094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)
# (10006, 12)

# %%
#remove Other from Gender
#condition based or filter based

df2=df2[df2['Gender']!='Other']
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9780 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       9780 non-null   int64
#  1   Gender                   9780 non-null   object
#  2   Coffee_Intake            9780 non-null   float64
#  3   Caffeine_mg              9780 non-null   float64
#  4   Sleep_Hours              9780 non-null   float64
#  5   Sleep_Quality            9780 non-null   object
#  6   Bmi                      9780 non-null   float64
#  7   Heart_Rate               9780 non-null   int64
#  8   Stress_Level             9780 non-null   object
#  9   Physical_Activity_Hours  9780 non-null   float64
#  10  Health_Issues            9780 non-null   object
#  11  Occupation               9780 non-null   object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 993.3+ KB

# %%
df2.head()
# Out:
#    ID  Gender  Coffee_Intake  Caffeine_mg  Sleep_Hours Sleep_Quality   Bmi  \
# 0   1    Male            3.5        328.1          7.5          Good  24.9
# 1   2    Male            1.0         94.1          6.2          Good  20.0
# 2   3    Male            5.3        503.7          5.9          Fair  22.7
# 3   4    Male            2.6        249.2          7.3          Good  24.7
# 4   5  Female            3.1        298.0          5.3          Fair  24.1
#
#    Heart_Rate Stress_Level  Physical_Activity_Hours Health_Issues Occupation
# 0          78          Low                     14.5            No      Other
# 1          67          Low                     11.0            No    Service
# 2          59       Medium                     11.2          Mild     Office
# 3          71          Low                      6.6          Mild      Other
# 4          76       Medium                      8.5          Mild    Student

# %% [markdown]
# # encoding
#  - map using dictionary
#  - LabelEncoder

# %%
#map
df2['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df2['Gender']=df2['Gender'].map({'Male': 0, 'Female': 1})

# %%
df2.head()
# Out:
#    ID  Gender  Coffee_Intake  Caffeine_mg  Sleep_Hours Sleep_Quality   Bmi  \
# 0   1       0            3.5        328.1          7.5          Good  24.9
# 1   2       0            1.0         94.1          6.2          Good  20.0
# 2   3       0            5.3        503.7          5.9          Fair  22.7
# 3   4       0            2.6        249.2          7.3          Good  24.7
# 4   5       1            3.1        298.0          5.3          Fair  24.1
#
#    Heart_Rate Stress_Level  Physical_Activity_Hours Health_Issues Occupation
# 0          78          Low                     14.5            No      Other
# 1          67          Low                     11.0            No    Service
# 2          59       Medium                     11.2          Mild     Office
# 3          71          Low                      6.6          Mild      Other
# 4          76       Medium                      8.5          Mild    Student

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder

sleep_quality_enc=LabelEncoder()
sleep_quality_enc.fit(df2['Sleep_Quality'])

print(sleep_quality_enc.classes_)
# print(sleep_quality_enc.inverse_transform(sleep_quality_enc.classes_))

df2['Sleep_Quality']= sleep_quality_enc.fit_transform(df2['Sleep_Quality'])

df2.head()
# Out:
# ['Excellent' 'Fair' 'Good' 'Poor']
#    ID  Gender  Coffee_Intake  Caffeine_mg  Sleep_Hours  Sleep_Quality   Bmi  \
# 0   1       0            3.5        328.1          7.5              2  24.9
# 1   2       0            1.0         94.1          6.2              2  20.0
# 2   3       0            5.3        503.7          5.9              1  22.7
# 3   4       0            2.6        249.2          7.3              2  24.7
# 4   5       1            3.1        298.0          5.3              1  24.1
#
#    Heart_Rate Stress_Level  Physical_Activity_Hours Health_Issues Occupation
# 0          78          Low                     14.5            No      Other
# 1          67          Low                     11.0            No    Service
# 2          59       Medium                     11.2          Mild     Office
# 3          71          Low                      6.6          Mild      Other
# 4          76       Medium                      8.5          Mild    Student

# %%
#handle duplicate values
df2.duplicated().sum()
df2.drop_duplicates(inplace=True)
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Create age groups (bins)
bins = [0, 18, 30, 45, 60, 100]
labels = ['0-17', '18-29', '30-44', '45-59', '60+']

df3=df.copy()
df3['Age Group'] = pd.cut(df3['Age'], bins=bins, labels=labels)

df3['Age Group'].value_counts()
# Out:
# Age Group
# 30-44    4509
# 18-29    2763
# 45-59    1653
# 0-17      935
# 60+       148
# Name: count, dtype: int64

# %%
#distribution of male vs female un different age groups

df3.head()
# Out:
#    ID  Age  Gender  Country  Coffee_Intake  Caffeine_mg  Sleep_Hours  \
# 0   1   40    Male  Germany            3.5        328.1          7.5
# 1   2   33    Male  Germany            1.0         94.1          6.2
# 2   3   42    Male  Brazil😂            5.3        503.7          5.9
# 3   4   53    Male  Germany            2.6        249.2          7.3
# 4   5   32  Female    Spain            3.1        298.0          5.3
#
#   Sleep_Quality   BMI  Heart_Rate Stress_Level  Physical_Activity_Hours  \
# 0          Good  24.9          78          Low                     14.5
# 1          Good  20.0          67          Low                     11.0
# 2          Fair  22.7          59       Medium                     11.2
# 3          Good  24.7          71          Low                      6.6
# 4          Fair  24.1          76       Medium                      8.5
#
#   Health_Issues Occupation  Smoking  Alcohol_Consumption Age Group
# ...

# %%
categories=df3.groupby(['Age Group', 'Gender']).size().unstack()

categories
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_58882/2956783565.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   categories=df3.groupby(['Age Group', 'Gender']).size().unstack()
# Gender     Female  Male  Other
# Age Group
# 0-17          466   447     22
# 18-29        1380  1317     66
# 30-44        2259  2147    103
# 45-59         827   794     32
# 60+            77    68      3

# %%
categories.plot(kind='bar', stacked=True, figsize=(10, 6))
# Out:
# <Axes: xlabel='Age Group'>

# %% [markdown]
# Distribution of males vs females is balanced among different age groups. Highest numbers of workers betwee 18 and 60.
