# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset
df= pd.read_csv('amazon_sales.csv', encoding='utf-8', index_col=0)
df
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/2554513002.py:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('amazon_sales.csv', encoding='utf-8', index_col=0)
#                    Order ID      Date                        Status  \
# index
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# ...

# %%
#view the columns

df.columns
# Out:
# Index(['Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df2=df[['Date', 'Status', 'Fulfilment', 'Sales Channel ',
       'ship-service-level', 'Category', 'Size',
       'Courier Status', 'Qty', 'Amount', 'ship-city',
       'ship-state', 'promotion-ids',
       'B2B', 'fulfilled-by']]

# %%
df2.head()
# Out:
#            Date                        Status Fulfilment Sales Channel   \
# index
# 0      04-30-22                     Cancelled   Merchant      Amazon.in
# 1      04-30-22  Shipped - Delivered to Buyer   Merchant      Amazon.in
# 2      04-30-22                       Shipped     Amazon      Amazon.in
# 3      04-30-22                     Cancelled   Merchant      Amazon.in
# 4      04-30-22                       Shipped     Amazon      Amazon.in
#
#       ship-service-level       Category Size Courier Status  Qty  Amount  \
# index
# 0               Standard            Set    S            NaN    0  647.62
# 1               Standard          kurta  3XL        Shipped    1  406.00
# 2              Expedited          kurta   XL        Shipped    1  329.00
# 3               Standard  Western Dress    L            NaN    0  753.33
# 4              Expedited            Top  3XL        Shipped    1  574.00
#
#          ship-city   ship-state  \
# index
# 0           MUMBAI  MAHARASHTRA
# ...

# %%
df['Sales Channel '].unique()
# Out:
# array(['Amazon.in', 'Non-Amazon'], dtype=object)

# %%
df2.rename(columns={'Sales Channel ':'Sales_channel', 'Courier Status': 'Courier_status'}, inplace=True )
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/3892550057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns={'Sales Channel ':'Sales_channel', 'Courier Status': 'Courier_status'}, inplace=True )

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128975 entries, 0 to 128974
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                128975 non-null  object
#  1   Status              128975 non-null  object
#  2   Fulfilment          128975 non-null  object
#  3   Sales_channel       128975 non-null  object
#  4   ship-service-level  128975 non-null  object
#  5   Category            128975 non-null  object
#  6   Size                128975 non-null  object
#  7   Courier_status      122103 non-null  object
#  8   Qty                 128975 non-null  int64
#  9   Amount              121180 non-null  float64
#  10  ship-city           128942 non-null  object
#  11  ship-state          128942 non-null  object
#  12  promotion-ids       79822 non-null   object
#  13  B2B                 128975 non-null  bool
#  14  fulfilled-by        39277 non-null   object
# ...

# %%
df2['Promotion'] = np.where(df2['promotion-ids'].isnull(), False, True)
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/337577189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Promotion'] = np.where(df2['promotion-ids'].isnull(), False, True)

# %%
df2.columns
# Out:
# Index(['Date', 'Status', 'Fulfilment', 'Sales_channel', 'ship-service-level',
#        'Category', 'Size', 'Courier_status', 'Qty', 'Amount', 'ship-city',
#        'ship-state', 'promotion-ids', 'B2B', 'fulfilled-by', 'Promotion'],
#       dtype='object')

# %%
df2.drop(columns=['promotion-ids'], inplace=True)
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/1810875309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['promotion-ids'], inplace=True)

# %%
df2
# Out:
#             Date                        Status Fulfilment Sales_channel  \
# index
# 0       04-30-22                     Cancelled   Merchant     Amazon.in
# 1       04-30-22  Shipped - Delivered to Buyer   Merchant     Amazon.in
# 2       04-30-22                       Shipped     Amazon     Amazon.in
# 3       04-30-22                     Cancelled   Merchant     Amazon.in
# 4       04-30-22                       Shipped     Amazon     Amazon.in
# ...          ...                           ...        ...           ...
# 128970  05-31-22                       Shipped     Amazon     Amazon.in
# 128971  05-31-22                       Shipped     Amazon     Amazon.in
# 128972  05-31-22                       Shipped     Amazon     Amazon.in
# 128973  05-31-22                       Shipped     Amazon     Amazon.in
# 128974  05-31-22                       Shipped     Amazon     Amazon.in
#
#        ship-service-level       Category Size Courier_status  Qty   Amount  \
# index
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128975 entries, 0 to 128974
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                128975 non-null  object
#  1   Status              128975 non-null  object
#  2   Fulfilment          128975 non-null  object
#  3   Sales_channel       128975 non-null  object
#  4   ship-service-level  128975 non-null  object
#  5   Category            128975 non-null  object
#  6   Size                128975 non-null  object
#  7   Courier_status      122103 non-null  object
#  8   Qty                 128975 non-null  int64
#  9   Amount              121180 non-null  float64
#  10  ship-city           128942 non-null  object
#  11  ship-state          128942 non-null  object
#  12  B2B                 128975 non-null  bool
#  13  fulfilled-by        39277 non-null   object
#  14  Promotion           128975 non-null  bool
# ...

# %%
df2['fulfilled-by'].unique()
# Out:
# array(['Easy Ship', nan], dtype=object)

# %%
df2['fulfilled-by'].fillna('Amazon', inplace=True)
df2
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/1061616078.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['fulfilled-by'].fillna('Amazon', inplace=True)
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/1061616078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128975 entries, 0 to 128974
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                128975 non-null  object
#  1   Status              128975 non-null  object
#  2   Fulfilment          128975 non-null  object
#  3   Sales_channel       128975 non-null  object
#  4   ship-service-level  128975 non-null  object
#  5   Category            128975 non-null  object
#  6   Size                128975 non-null  object
#  7   Courier_status      122103 non-null  object
#  8   Qty                 128975 non-null  int64
#  9   Amount              121180 non-null  float64
#  10  ship-city           128942 non-null  object
#  11  ship-state          128942 non-null  object
#  12  B2B                 128975 non-null  bool
#  13  fulfilled-by        128975 non-null  object
#  14  Promotion           128975 non-null  bool
# ...

# %%
df['Courier Status'].unique()
# Out:
# array([nan, 'Shipped', 'Cancelled', 'Unshipped'], dtype=object)

# %%
df2.dropna(inplace=True)
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/1761232742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 116016 entries, 1 to 128974
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                116016 non-null  object
#  1   Status              116016 non-null  object
#  2   Fulfilment          116016 non-null  object
#  3   Sales_channel       116016 non-null  object
#  4   ship-service-level  116016 non-null  object
#  5   Category            116016 non-null  object
#  6   Size                116016 non-null  object
#  7   Courier_status      116016 non-null  object
#  8   Qty                 116016 non-null  int64
#  9   Amount              116016 non-null  float64
#  10  ship-city           116016 non-null  object
#  11  ship-state          116016 non-null  object
#  12  B2B                 116016 non-null  bool
#  13  fulfilled-by        116016 non-null  object
#  14  Promotion           116016 non-null  bool
# ...

# %%
df2.head(10)
# Out:
#            Date                        Status Fulfilment Sales_channel  \
# index
# 1      04-30-22  Shipped - Delivered to Buyer   Merchant     Amazon.in
# 2      04-30-22                       Shipped     Amazon     Amazon.in
# 4      04-30-22                       Shipped     Amazon     Amazon.in
# 5      04-30-22                       Shipped     Amazon     Amazon.in
# 6      04-30-22                       Shipped     Amazon     Amazon.in
# 7      04-30-22  Shipped - Delivered to Buyer   Merchant     Amazon.in
# 9      04-30-22                       Shipped     Amazon     Amazon.in
# 10     04-30-22                       Shipped     Amazon     Amazon.in
# 11     04-30-22                       Shipped     Amazon     Amazon.in
# 12     04-30-22  Shipped - Delivered to Buyer   Merchant     Amazon.in
#
#       ship-service-level Category Size Courier_status  Qty  Amount  \
# index
# 1               Standard    kurta  3XL        Shipped    1   406.0
# ...

# %%
#split date into 3 columns day, month, year
df2['Date'] = pd.to_datetime(df2['Date'])
df2['Day'] = df2['Date'].dt.day
df2['Month'] = df2['Date'].dt.month
df2['Year'] = df2['Date'].dt.year
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/3346892987.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df2['Date'] = pd.to_datetime(df2['Date'])
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/3346892987.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date'] = pd.to_datetime(df2['Date'])
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/3346892987.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df2
# Out:
#              Date                        Status Fulfilment Sales_channel  \
# index
# 1      2022-04-30  Shipped - Delivered to Buyer   Merchant     Amazon.in
# 2      2022-04-30                       Shipped     Amazon     Amazon.in
# 4      2022-04-30                       Shipped     Amazon     Amazon.in
# 5      2022-04-30                       Shipped     Amazon     Amazon.in
# 6      2022-04-30                       Shipped     Amazon     Amazon.in
# ...           ...                           ...        ...           ...
# 128970 2022-05-31                       Shipped     Amazon     Amazon.in
# 128971 2022-05-31                       Shipped     Amazon     Amazon.in
# 128972 2022-05-31                       Shipped     Amazon     Amazon.in
# 128973 2022-05-31                       Shipped     Amazon     Amazon.in
# 128974 2022-05-31                       Shipped     Amazon     Amazon.in
#
#        ship-service-level       Category Size Courier_status  Qty  Amount  \
# index
# ...

# %%
df2['Order_total']= df2['Qty'] * df2['Amount']
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/3754107702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Order_total']= df2['Qty'] * df2['Amount']

# %%
df2.drop(columns=['Sales_channel'], inplace=True)
# Out:
# /var/folders/5g/7m5tb_kn729bgtcb25k58dlc0000gn/T/ipykernel_6254/1594145413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['Sales_channel'], inplace=True)

# %%
df2.to_csv('amazon_sales_cleaned.csv', index=False)
